# %%
import matplotlib.pyplot as plt
xs = [692,1201]
ys = [3820,7377]
circle1 = plt.Circle((2857, 6285), 1875, color='r')
plt.plot(xs,ys,'k-')
plt.xlim(0,10000)
plt.ylim(0,10000)
plt.gca().add_patch(circle1)
plt.gca().set_aspect('equal')
plt.draw()
